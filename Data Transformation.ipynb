# %% [markdown]
# ## World Food Program (Data Transformation)

# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import re
import requests

# %% [markdown]
# ## Read The Data

# %%
wfp_df = pd.read_csv('wfp_market_food_prices_original.csv', encoding='latin-1')

# %%
wfp_df.shape
# Out:
# (743914, 10)

# %% [markdown]
# ### Columns

# %%
list(wfp_df.columns)
# Out:
# ['CountryName',
#  'MarketName',
#  'CommodityName',
#  'CurrencyName',
#  'MarketTypeName',
#  'MeasurementName',
#  'Month',
#  'Year',
#  'Price',
#  'CommeditySource']

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### Check the duplicated data

# %%
duplicated = wfp_df.duplicated()
len(wfp_df[duplicated])
# Out:
# 0

# %% [markdown]
# Cool, There are no duplicated data

# %% [markdown]
# #### Clean 'CountryName'

# %%
wfp_df['CountryName'] = wfp_df['CountryName'].str.strip()
sorted(list(wfp_df['CountryName'].unique()))
# Out:
# ['Afghanistan',
#  'Algeria',
#  'Armenia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Chad',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Democratic Republic of the Congo',
#  'Djibouti',
#  'Egypt',
#  'El Salvador',
#  'Ethiopia',
#  'Gambia',
#  'Georgia',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Iran  (Islamic Republic of)',
#  'Iraq',
#  'Jordan',
#  'Kenya',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mozambique',
#  'Myanmar',
#  'Nepal',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Rwanda',
#  'Senegal',
#  'Somalia',
#  'South Sudan',
#  'Sri Lanka',
#  'State of Palestine',
#  'Sudan',
#  'Swaziland',
#  'Syrian Arab Republic',
#  'Tajikistan',
#  'Timor-Leste',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Republic of Tanzania',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %% [markdown]
# CountryName Looks Good

# %% [markdown]
# #### Clean 'MarketName'

# %%
wfp_df['MarketName'] = wfp_df['MarketName'].str.strip()
sorted(list(wfp_df['MarketName'].unique()))
# Out:
# ['Aba',
#  'Abaala',
#  'Abala',
#  'Abalak',
#  'Abeche',
#  'Abengourou',
#  'Abi Adi',
#  'Abomsa',
#  'Accra',
#  'Achham',
#  'Addaleh Town',
#  'Addis Ababa',
#  'Adel Bagrou',
#  'Aden City',
#  'Aderbissinat',
#  'Adigrat',
#  'Adjame',
#  'Adoumri',
#  'Adwa',
#  'Afreen',
#  'Agadez Commune',
#  'Agartala',
#  'Agra',
#  'Ahmedabad',
#  'Ahuachapan',
#  'Ai Cheng',
#  'Aizwal',
#  'Ajeber',
#  'Ajloun',
#  'Akkar',
#  'Al  Aqaba',
#  'Al Balqa',
#  'Al Bayda City',
#  'Al Fashir',
#  'Al Ghaidha',
#  'Al Hawta Town',
#  'Al Hazum',
#  'Al Hudaydah City (Hodieda)',
#  'Al Jabeen',
#  'Al Karak',
#  'Al Mafraq',
#  'Al Tafilah',
#  "Al-Cha'ar",
#  'Al-Muthana',
#  'Al-Tall',
#  'Alamata',
#  'Alanbar',
#  'Alaotra Mangoro',
#  'Alel Than Kyaw',
#  'Aleppo',
#  'Aley',
#  'Algiers',
#  'Ali Sabieh',
#  'Almayadin',
#  'Alto Molocue',
#  'Am Timan',
#  'Amaro',
#  'Ambo',
#  'Amboasary',
#  'Ambovombe-androy',
#  'Amman',
#  "Amoron'I Mania",
#  'Ampanihy',
#  'Ampara',
#  'Amran City',
#  'Amritsar',
#  'Analamanga',
#  'Analanjirofo',
#  'Anderamboukane',
#  'Androy',
#  'Angonia',
#  'Anlong Veng',
#  'Anosy',
#  'Ansongo',
#  'Antananarivo',
#  'Anuradhapura',
#  'Aoujeft',
#  'Arlit',
#  'Armavir',
#  'Armenia',
#  'Aroresa',
#  'Arslanbob',
#  'Arta',
#  'Arusha',
#  'Asayta',
#  'Assela',
#  'At-Bashi',
#  'Atsimo Andrefana',
#  'Atsimo Atsinanana',
#  'Atsinanana',
#  'Attapeu',
#  'Attaq Town',
#  'Auserd',
#  'Awassa Zuriya',
#  'Aweil (Town)',
#  'Ayorou',
#  'Azove',
#  'A\x92zaz',
#  'Baabda',
#  'Baalbeck',
#  'Babati',
#  'Babile',
#  'Babylon',
#  'Badaguichiri',
#  'Badalabougou',
#  'Badinko',
#  'Badulla',
#  'Baghdad',
#  'Baher Dar',
#  'Bakandi',
#  'Bakau',
#  'Bakel',
#  'Bakin Birgi',
#  'Balaka',
#  'Balayara',
#  'Balibo',
#  'Balykchy',
#  'Bamako',
#  'Bambara Maoude',
#  'Bambari',
#  'Bambey',
#  'Bamyan',
#  'Ban Wai',
#  'Bancoma',
#  'Bandiagara',
#  'Bandim',
#  'Bandundu ville',
#  'Banfora',
#  'Bangassou',
#  'Bangui',
#  'Bangula',
#  'Bani Matar',
#  'Banikoara',
#  'Banjul',
#  'Bankass',
#  'Banke',
#  'Bankilare',
#  'Bansang',
#  'Banteay Meanchey',
#  'Baqui',
#  'Barclayville',
#  'Barisal Division',
#  'Barkeol',
#  'Barranquilla',
#  'Base',
#  'Basra',
#  'Basse Santa su',
#  'Bat Doeng',
#  'Bathinda',
#  'Bati',
#  'Batken',
#  'Batroun',
#  'Battambang',
#  'Batticaloa',
#  'Baucau',
#  'Bazar-Korgon',
#  'Bechare',
#  'Becora',
#  'Beddenno',
#  'Bedessa',
#  'Beira',
#  'Beirut',
#  'Bekily',
#  'Beletweine',
#  'Beloha',
#  'Bembeke turn off',
#  'Benech',
#  'Bengaluru',
#  'Beni',
#  'Bentiu',
#  'Berbera',
#  'Berd',
#  'Berea',
#  'Bethlehem',
#  'Betioky',
#  'Betsiboka',
#  'Bhagalpur',
#  'Bhamo',
#  'Bhojpur',
#  'Bhopal',
#  'Bhubaneshwar',
#  'Bignona',
#  'Bindura',
#  'Binga centre',
#  'Bint Jbeil',
#  'Birambo',
#  'Birkelane',
#  'Birnin Gaoure',
#  'Bishkek',
#  'Biu',
#  'Bla',
#  'Bo Waterside',
#  'Boeny',
#  'Boeung Kok',
#  'Boghe',
#  'Bogota',
#  'Bohicon',
#  'Boke',
#  'Bokeo',
#  'Bol',
#  'Bolga',
#  'Boma',
#  'Bongolava',
#  'Bongor',
#  'Boni',
#  'Bonkaney',
#  'Bopolu',
#  'Bor',
#  'Borama',
#  'Borikhamxay',
#  'Bossaso',
#  'Bouake',
#  'Bougouni',
#  'Boujdour',
#  'Bourem',
#  'Bourem Inaly',
#  'Bousse',
#  'Bouza',
#  'Bowe',
#  'Bria',
#  'Brikama',
#  'BrikamaBa',
#  'Bucaramanga',
#  'Buchanan',
#  'Bugarama',
#  'Buhanda',
#  'Bujumbura',
#  'Bukavu',
#  'Bukoba',
#  'Bumazi',
#  'Bunia',
#  'Burco',
#  'Bure',
#  'Bushenge',
#  'Butare',
#  'Butembo',
#  'Butha Buthe',
#  'Buthidaung',
#  'Bvumbwe',
#  'Byangabo',
#  'Bystrovka',
#  'Byumba',
#  'Cailaco',
#  'Cali',
#  'Cap-Haitien',
#  'Cape Coast',
#  'Cartagena',
#  'Castors',
#  'Catarman',
#  'Cayes',
#  'Cebu City',
#  'Ceerigaabo',
#  'Central Market (KSP)',
#  'Central Market (PST)',
#  'Cestos City',
#  'Chadakori',
#  'Chadiza',
#  'Chaek',
#  'Chalatenango',
#  'Chama',
#  'Chamama',
#  'Champassack',
#  'Chandigarh',
#  'Chatoloma',
#  'Chavuma',
#  'Checheche',
#  'Chennai',
#  'Cherkasy',
#  'Chernihiv',
#  'Chernivtsi',
#  'Chetimari',
#  'Chheu Kach Thmei',
#  'Chheu Tom',
#  'Chibombo',
#  'Chiengi',
#  'Chikonohono',
#  'Chikwawa',
#  'Chililabombwe',
#  'Chilubi',
#  'Chilumba',
#  'Chimbiya',
#  'Chimoio',
#  'Chingola',
#  'Chinsali',
#  'Chintheche',
#  'Chipata',
#  'Chiradzulu',
#  'Chitipa',
#  'Chittagong Division',
#  'Chitwan',
#  'Chokwe',
#  'Choma',
#  'Chongwe',
#  'Chouf',
#  'Chying Thung',
#  'Cobija',
#  'Cochabamba City',
#  'Cojutepeque',
#  'Colombo City',
#  'Come',
#  'Comoro',
#  'Congo - Nil',
#  'Cuamba',
#  'Cucuta',
#  'Cuttack',
#  'Dagana',
#  'Dakar',
#  'Dakhla',
#  'Dakoro',
#  'Daloa',
#  'Damassack (CBM)',
#  'Damaturu',
#  'Damazin',
#  'Dan Issa',
#  'Dan-Goulbi',
#  'Dandume',
#  'Dantokpa',
#  'Dar Es Salaam',
#  'Daraa',
#  'Davao City',
#  'Dawanau',
#  'Debark',
#  'Debre Birhan',
#  'Debre Markos',
#  'Deder',
#  'Dedougou',
#  'Dehradun',
#  'Deir Ezzor',
#  'Delhi',
#  'Delo',
#  'Derashe',
#  'Desse',
#  'Dhaka Division',
#  'Dhamar City',
#  'Dhankuta',
#  'Dhanusha',
#  'Dharwad',
#  'Diafarabe',
#  'Diakawere',
#  'Diakhao',
#  'Diallassagou',
#  'Diama Gadio',
#  'Diana',
#  'Diaobe',
#  'Dibida',
#  'Diebougou',
#  'Diema',
#  'Diffa Commune',
#  'Dikhil',
#  'Dili',
#  'Dimapur',
#  'Dindigul',
#  'Dioila',
#  'Dioli Mandakh',
#  'Diondiori',
#  'Dioro',
#  'Diourbel',
#  'Dire',
#  'Dire Dawa',
#  'Djebock',
#  'Djenne',
#  'Djibo',
#  'Djikoroni',
#  'Djougou',
#  'Djougountourou',
#  'Dnipropetrovsk',
#  'Dobolu',
#  'Dodoma',
#  'Dogofri',
#  'Dogon Kiria',
#  'Dogondoutchi',
#  'Dohuk',
#  'Dole',
#  'Dombotombo',
#  'Donetska',
#  'Dori',
#  'Dosso Commune',
#  'Doti',
#  'Douekire',
#  'Douentza',
#  'Dougouolo',
#  'Dowa',
#  'Duala',
#  'Duekoue',
#  'Dulibadzimu Market',
#  'Dungass',
#  'Dushanbe',
#  'Dwangwa',
#  'Dyala',
#  'Ebinat',
#  'Eddein',
#  'Edlib',
#  'Ejura',
#  'Ekrema',
#  'El Fula',
#  'El Geneina',
#  'El Metn',
#  'El Obeid',
#  'Eldoret',
#  'Embangweni',
#  'Erbil',
#  'Ernakulam',
#  'Essau / Barra',
#  "Fada N'Gourma",
#  'Fadjiguila',
#  'Faladie',
#  'Falam',
#  'Fana',
#  'Farafenni',
#  'Fatick',
#  'Fatine',
#  'Fayzabad',
#  'Figuil',
#  'Filingue',
#  'Fish Town',
#  'Forgho',
#  'Fort-Dauphin',
#  'Foya',
#  'Gaalkacyo',
#  'Gacurabwenge',
#  'Gahanga',
#  'Gakenke',
#  'Galle',
#  'Galmi',
#  'Gambela',
#  'Gamo Gofa',
#  'Gampaha',
#  'Gangaw',
#  'Ganta',
#  'Gao',
#  'Garare',
#  'Garayang',
#  'Gardez',
#  'Garhanga',
#  'Garissa',
#  'Garoua',
#  'Garowe',
#  'Gasarenda',
#  'Gaseke',
#  'Gashyushya',
#  'Gathie Loumo',
#  'Gatore',
#  'Gavar',
#  'Gaya',
#  'Gaza',
#  'Gaza North',
#  'Gbadolite',
#  'Gbarma',
#  'Gbarnga',
#  'Gharm',
#  'Ghor',
#  'Gikongoro',
#  'Gisenyi',
#  'Gitega',
#  'Giwa',
#  'Glazoue',
#  'Gode',
#  'Goma',
#  'Gombe',
#  'Gonaives',
#  'Gonder',
#  'Gordamole',
#  'Gore',
#  'Gorom Gorom',
#  'Gorongoza',
#  'Gossas',
#  'Gotheye',
#  'Goudoumaria',
#  'Gouille Mbeuth',
#  'Gounambougou',
#  'Goundam',
#  'Gourcy',
#  'Goure',
#  'Gourma Rharous',
#  'Grand marche (Nzerekore)',
#  'Grand marche/Fond Ntie-Ntie/Nkouikou',
#  'Greenville',
#  'Gueckedou',
#  'Guelwongo',
#  'Gueule Tapee',
#  'Guidan Roumdji',
#  'Guider',
#  'Guidiguir',
#  'Guidimouni',
#  'Guiglo',
#  'Gujungu',
#  'Gulu',
#  'Gurgaon',
#  'Guwahati',
#  'Gwalior',
#  'Gwanda town',
#  'Gwandu',
#  'Gwembe',
#  'Hajar Aswad',
#  'Hakha',
#  'Hali-Laren',
#  'Hama',
#  'Hambantota',
#  'Haoussa Foulane',
#  'Haradh Town',
#  'Hargeysa',
#  'Harobanda',
#  'Harper',
#  'Hasbaya',
#  'Hassakeh',
#  'Haute Matsiatra',
#  'Hawzien',
#  'Hebron',
#  'Hermel',
#  'Herson',
#  'Hewe',
#  'Hinche',
#  'Hirat',
#  'Hisar',
#  'Ho',
#  'Hola (Tana River)',
#  'Hombori',
#  'Homs',
#  'Honai',
#  'Hopone',
#  'Hossana',
#  'Hsihseng',
#  'Htilin',
#  'Huaphanh',
#  'Humera',
#  'Hwange Town Bus Terminus',
#  'Hyderabad',
#  'Ibadan',
#  'Ibb City',
#  'Iganga',
#  'Ihorombe',
#  'Illam',
#  'Illela (CBM)',
#  'Iloilo City',
#  'Indore',
#  'Ingall',
#  'Inhambane',
#  'Inn Din',
#  'Inshaat',
#  'Irbid',
#  'Iringa',
#  'Isfana',
#  'Isiro',
#  'Isoka',
#  'Itanagar',
#  'Itasy',
#  'Itezhi-tezhi',
#  'Ivano-Frankivsk',
#  'Jabalpur',
#  'Jableh',
#  'Jacmel',
#  'Jaffna',
#  'Jaipur',
#  'Jalal-Abad',
#  'Jalalabad',
#  'Jali',
#  'Jammu',
#  'Jandar',
#  'Jarash',
#  'Jau',
#  'Jbeil',
#  'Jenda',
#  'Jenin',
#  'Jeremie',
#  'Jericho',
#  'Jhapa',
#  'Jibia (CBM)',
#  'Jijiga',
#  'Jimma',
#  'Jinja',
#  'Jodhpur',
#  'Jumla',
#  'Kabacuzi',
#  'Kabalo',
#  'Kabarondo',
#  'Kabaya',
#  'Kabompo',
#  'Kabul',
#  'Kabwe',
#  'Kabwe Rural',
#  'Kabwe Urban',
#  'Kadugli',
#  'Kaffrine',
#  'Kafue',
#  'Kailali',
#  'Kaiyrma-Aryk',
#  'Kajiado',
#  'Kakata',
#  'Kalabo',
#  'Kalale',
#  'Kalay',
#  'Kalemie',
#  'Kalomo',
#  'Kalulushi',
#  'Kalutara',
#  'Kamembe',
#  'Kamina',
#  'Kamishly',
#  'Kampong Cham',
#  'Kampong Chheuteal',
#  'Kampong Chhnang',
#  'Kampong Speu',
#  'Kampong Thum',
#  'Kampot',
#  'Kananga',
#  'Kandahar',
#  'Kandy',
#  'Kanembakache',
#  'Kankossa',
#  'Kanpur',
#  'Kantchari (CBM)',
#  'Kaolack',
#  'Kaoma',
#  'Kaou',
#  'Kapchorwa',
#  'Kapiri-Mposhi',
#  'Kaputa',
#  'Kara-Balta',
#  'Kara-Suu',
#  'Karabak',
#  'Karachi',
#  'Karakol',
#  'Karambi',
#  'Karasuu',
#  'Karati',
#  'Karbala',
#  'Karenge',
#  'Karnal',
#  'Karofane',
#  'Karonga',
#  'Kasama',
#  'Kasempa',
#  'Kasiya',
#  'Kaski',
#  'Kassala',
#  'Kasungu',
#  'Katako',
#  'Katete',
#  'Kathmandu',
#  'Kati',
#  'Katiola',
#  'Kaung Ming Sang',
#  'Kaur Wharf Town',
#  'Kaura Namoda',
#  'Kawambwa',
#  'Kaya',
#  'Kayenzi',
#  'Kayes Centre',
#  "Kayes N'Dy",
#  'Kayes Plateau',
#  'Kazoe',
#  'Kazungula',
#  'Kedougou',
#  'Kegalle',
#  'Keita',
#  'Kelo',
#  'Ker Pate Kore',
#  'Kerben',
#  'Kerewan',
#  'Kerkuk',
#  'Kerou',
#  'Kersa',
#  'Keserwan',
#  'Ketou',
#  'Keur I. Yacine',
#  'Kha Mauck Siek',
#  'Khammouane',
#  'Khan Arnabeh',
#  'Kharkivka',
#  'Khmelnytsky',
#  'Khorog',
#  'Khujand',
#  'Khulna Division',
#  'Kibirizi',
#  'Kiboga',
#  'Kibungo',
#  'Kibuye',
#  'Kicukiro',
#  'Kidal',
#  'Kiev',
#  'Kifosso',
#  'Kigoma',
#  'Kikara',
#  'Kikwit',
#  'Kilifi',
#  'Kilinochchi',
#  'Kimironko',
#  'Kimisagara',
#  'Kindu',
#  'Kinshasa',
#  'Kirambo',
#  'Kirintim',
#  'Kirovograd',
#  'Kirtachi',
#  'Kirundo',
#  'Kisangani',
#  'Kissidougou',
#  'Kisumu',
#  'Kita',
#  'Kitui',
#  'Kitwe',
#  'Kizi',
#  'Kobo',
#  'Koforidua',
#  'Kohima',
#  'Kok-Say',
#  'Kolda',
#  'Kolkata',
#  'Kolokani',
#  'Kolwezi',
#  'Kombai',
#  'KonKyan',
#  'Kong Chang',
#  'Kongoussi',
#  'Konni',
#  'Konyo Konyo',
#  'Korem',
#  'Korhogo',
#  'Kornaka',
#  'Koro',
#  'Koronadal',
#  'Kosti',
#  'Kota',
#  'Koudougou',
#  'Koulikoro Ba',
#  'Koulikoro Gare',
#  'Koulogon',
#  'Koumantou',
#  'Koundoumaoua',
#  'Koungueul',
#  'Koura',
#  'Kouremale',
#  'Kourouma',
#  'Koury',
#  'Kousseri',
#  'Kouthiaba',
#  'Koutiala',
#  'Kozhidoke',
#  'Kralanh',
#  'Kratie',
#  'Kuajok',
#  'Kumasi',
#  'Kuntaur',
#  'Kurgan-Tyube',
#  'Kurunegala',
#  'Kutkai',
#  'Kwinella Nya Kunda',
#  'Kyein Chung',
#  'Kyzyl-Adyr',
#  'Kyzyl-Tuu',
#  'La Paz City',
#  'La Terminal',
#  'La Trinidad',
#  'La Union',
#  'Lafiabougou',
#  'Laga',
#  'Lagos',
#  'Lahore',
#  'Lamin',
#  'Lashio',
#  'Latri kunda',
#  'Lattakia',
#  'Laukai',
#  'Layoun',
#  'Legazpi',
#  'Leo',
#  'Lere',
#  'Leribe',
#  'Lexeiba1',
#  'Lichinga',
#  'Likasi',
#  'Lilongwe',
#  'Lima',
#  'Limbe',
#  'Lindi',
#  'Lingayen',
#  'Lira',
#  'Livingstone',
#  'Liwonde',
#  'Lizulu',
#  'Lodwar (Turkana)',
#  'Loga',
#  'Logone-Birni',
#  'Long Tan',
#  'Louga',
#  'Loulouni',
#  'Luang Prabang',
#  'Luangnamtha',
#  'Luangwa',
#  'Luanshya',
#  'Lubumbashi',
#  'Luchenza',
#  'Lucknow',
#  'Ludhiana',
#  'Luhanska',
#  'Lukulu',
#  'Lundazi',
#  'Lungngo',
#  'Lunzu',
#  'Lusaka',
#  'Lusaka Rural',
#  'Lusaka Urban',
#  'Luwingu',
#  'Lviv',
#  "M'Pessoba",
#  'Maan',
#  'Mabo',
#  'Macina',
#  'Mada',
#  'Madaba',
#  'Madingring',
#  'Madisi',
#  'Mafeteng',
#  'Magaria',
#  'Maghama',
#  'Magnambougou',
#  'Magta-lahjar',
#  'Magway',
#  'Mahoko',
#  'Mahweet City',
#  'Mai Adoua (CBM)',
#  'Mai Gatari (CBM)',
#  'Maidjirgui',
#  'Maiduguri',
#  'Maine Soroa',
#  'Mako',
#  'Malakal',
#  'Malanville (CBM)',
#  'Maliana',
#  'Malomo',
#  'Mambwe',
#  'Man',
#  'Man Pan',
#  'Man Ton Pa',
#  'Man Tone',
#  'Mandava',
#  'Mandera',
#  'Mandi',
#  'Mangaize',
#  'Mangochi',
#  'Manica',
#  'Manila',
#  'Mankessim',
#  'Mannar',
#  'Mansa',
#  'Mansi',
#  'Mao',
#  'Maputo',
#  'Maradi Commune',
#  'Marche central',
#  'Marib City',
#  'Marigat (Baringo)',
#  'Marjayoun',
#  'Marsabit',
#  'Masaiti',
#  'Maseru',
#  'Mashta Al Helou',
#  'Massinga',
#  'Matadi',
#  'Matale',
#  'Matam',
#  'Matameye',
#  'Matara',
#  'Matimba',
#  'Matupi',
#  'Maungdaw',
#  'Maxixe',
#  'Mayahi',
#  'Mayaka',
#  'Maymana',
#  'Mayo Oulo',
#  'Mazabuka',
#  'Mazar',
#  'Mbafaye',
#  'Mbagne',
#  'Mbaiboum',
#  'Mbala',
#  'Mbandaka',
#  'Mbar',
#  'Mbarara',
#  'Mbare',
#  'Mbeya',
#  'Mbout',
#  'Mbuji-mayi',
#  'Mchinji',
#  'Medellin',
#  'Mederdra',
#  'Medine',
#  'Mekele',
#  'Melaky',
#  'Menabe',
#  'Menaka',
#  'Mereto',
#  'Merti',
#  'Mesiaf',
#  'Meti',
#  'Migowi',
#  'Mikalou',
#  'Milange',
#  'Milenge',
#  'Min Kan',
#  'Mindat',
#  'Minieh-Dannieh',
#  'Missan',
#  'Missirah',
#  'Misuku',
#  'Mitundu',
#  'Mkanda',
#  'Mkushi',
#  'Moba',
#  'Mocuba',
#  'Moe Mauk',
#  'Moghambo',
#  "Mohale's Hoek",
#  'Mokhotlong',
#  'Mokko',
#  'Mombasa',
#  'Monaragala',
#  'Mondul Kiri',
#  'Mongo',
#  'Mongu',
#  'Monimpebougou',
#  'Monkey Bay',
#  'Montepuez',
#  'Monteria',
#  'Monze',
#  'Monzombo',
#  'Mopti Digue',
#  'Mopti Guangal',
#  'Morang',
#  'Morhtai',
#  'Morogoro',
#  'Moshi',
#  'Mosul',
#  'Mota',
#  'Moudjeria',
#  'Moundou',
#  'Moungali',
#  'Mount Darwin',
#  'Moussoro',
#  'Mpal',
#  'Mpamba',
#  'Mpika',
#  'Mponela',
#  'Mpongwe',
#  'Mporokoso',
#  'Mpulungu',
#  'Mtakataka',
#  'Mtwara',
#  'Mubi',
#  'Mucheke',
#  'Mufulira',
#  'Mufumbwe',
#  'Mugina',
#  'Muhanga',
#  'Muhondo',
#  'Mukalla City',
#  'Mukamira',
#  'Mukarange',
#  'Mulaitivu',
#  'Mulindi',
#  'Muloza',
#  'Multan',
#  'Mumbai',
#  'Mumbwa',
#  'Mungwi',
#  'Mupandawana',
#  'Murambinda',
#  'Murehwa',
#  'Murombedzi',
#  'Musanze',
#  'Muse',
#  'Musenyi',
#  'Musha',
#  'Musoma',
#  'Mutarara',
#  'Muyinga',
#  'Mwansambo',
#  'Mwanza',
#  'Mwene-Ditu',
#  'Mwense',
#  'Mwinilunga',
#  'Myin Hlut',
#  'Mykolaiv',
#  'Mzereb',
#  'Mzimba',
#  'Mzuzu',
#  "N'Dali",
#  "N'Doffane",
#  'Nabatiyeh',
#  'Nablus',
#  'Nacala',
#  'Nagpur',
#  'Nairobi',
#  'Najaf',
#  'Nakonde',
#  'Nakuru',
#  'Nam Kam',
#  'Nam San Yang',
#  'Nambuma',
#  ...]

# %% [markdown]
# There are many market names, and there is not any dirty data

# %% [markdown]
# #### Clean "CommodityName"

# %%
wfp_df['CommodityName'] = wfp_df['CommodityName'].str.strip()
sorted(list(wfp_df['CommodityName'].unique()))
# Out:
# ['Apples',
#  'Apples (red)',
#  'Avocados',
#  'Bananas',
#  'Bananas (medium size)',
#  'Beans',
#  'Beans (black)',
#  'Beans (butter)',
#  'Beans (catarino)',
#  'Beans (dry)',
#  'Beans (fava, dry)',
#  'Beans (green, fresh)',
#  'Beans (haricot)',
#  'Beans (kidney red)',
#  'Beans (kidney white)',
#  'Beans (kidney)',
#  'Beans (magnum)',
#  'Beans (mung)',
#  'Beans (niebe)',
#  'Beans (niebe, white)',
#  'Beans (red)',
#  'Beans (red, fresh)',
#  'Beans (silk red)',
#  'Beans (string)',
#  'Beans (sugar)',
#  'Beans (sugar-red)',
#  'Beans (white)',
#  'Beans(mash)',
#  'Beetroots',
#  'Blackberry',
#  'Bread',
#  'Bread (bakery)',
#  'Bread (brown)',
#  'Bread (common)',
#  'Bread (first grade flour)',
#  'Bread (high grade flour)',
#  'Bread (khoboz)',
#  'Bread (pita)',
#  'Bread (rye)',
#  'Bread (shop)',
#  'Bread (wheat)',
#  'Broccoli',
#  'Buckwheat grits',
#  'Bulgur',
#  'Butter',
#  'Cabbage',
#  'Carrots',
#  'Cashew',
#  'Cassava',
#  'Cassava (chikwangue)',
#  'Cassava (cossette)',
#  'Cassava (dry)',
#  'Cassava (fresh)',
#  'Cassava flour',
#  'Cassava leaves',
#  'Cassava meal',
#  'Cassava meal (gari)',
#  'Cauliflower',
#  'Charcoal',
#  'Cheese',
#  'Cheese (dry)',
#  'Cheese (goat)',
#  'Cheese (picon)',
#  'Cheese (white, boiled)',
#  'Chickpeas',
#  'Chickpeas (imported)',
#  'Chickpeas (local)',
#  'Chili (green)',
#  'Chili (red)',
#  'Cocoa',
#  'Cocoa (powder, not sweetened)',
#  'Coffee',
#  'Coffee (instant)',
#  'Cornstarch',
#  'Cotton',
#  'Cowpeas',
#  'Cowpeas (brown)',
#  'Cowpeas (white)',
#  'Cucumbers',
#  'Cucumbers (greenhouse)',
#  'Curd',
#  'Dates',
#  'Eggplants',
#  'Eggs',
#  'Eggs (imported)',
#  'Eggs (white, AA)',
#  'Exchange rate',
#  'Exchange rate (unofficial)',
#  'Fat (salo)',
#  'Fish',
#  'Fish (appolo)',
#  'Fish (bonga)',
#  'Fish (canned)',
#  'Fish (catfish)',
#  'Fish (dry)',
#  'Fish (fresh)',
#  'Fish (frozen)',
#  'Fish (red snapper)',
#  'Fish (salted)',
#  'Fish (sardine, canned)',
#  'Fish (smoked)',
#  'Fish (snake head)',
#  'Fish (tilapia)',
#  'Fish (tilapia, farmed)',
#  'Fish (tuna, canned)',
#  'Fonio',
#  'Fuel (diesel)',
#  'Fuel (gas)',
#  'Fuel (kerosene)',
#  'Fuel (petrol-gasoline)',
#  'Gari (white)',
#  'Gari (yellow)',
#  'Garlic',
#  'Garlic (small)',
#  'Ghee (artificial)',
#  'Ghee (natural)',
#  'Ghee (vanaspati)',
#  'Groundnuts',
#  'Groundnuts (Mix)',
#  'Groundnuts (large, shelled)',
#  'Groundnuts (paste)',
#  'Groundnuts (shelled)',
#  'Groundnuts (small, shelled)',
#  'Groundnuts (unshelled)',
#  'Guava',
#  'Labaneh',
#  'Lentils',
#  'Lentils (imported)',
#  'Lentils (masur)',
#  'Lentils (moong)',
#  'Lentils (urad)',
#  'Lettuce',
#  'Livestock (Goat)',
#  'Livestock (Sheep)',
#  'Livestock (cattle)',
#  'Livestock (goat, medium-sized castrated male)',
#  'Livestock (hen)',
#  'Livestock (pig)',
#  'Livestock (sheep, medium-sized castrated male)',
#  'Livestock (sheep, one-year-old alive female)',
#  'Livestock (sheep, two-year-old male)',
#  'Maize',
#  'Maize (imported)',
#  'Maize (local)',
#  'Maize (white)',
#  'Maize (yellow)',
#  'Maize flour',
#  'Maize flour (imported)',
#  'Maize flour (white)',
#  'Maize meal',
#  'Maize meal (local)',
#  'Maize meal (white, breakfast)',
#  'Maize meal (white, first grade)',
#  'Maize meal (white, roller)',
#  'Maize meal (white, with bran)',
#  'Maize meal (white, without bran)',
#  'Mangoes',
#  'Meat (beef)',
#  'Meat (beef, canned)',
#  'Meat (beef, chops with bones)',
#  'Meat (beef, first quality)',
#  'Meat (beef, minced)',
#  'Meat (beef, second quality)',
#  'Meat (beef, without bones)',
#  'Meat (buffalo, first quality)',
#  'Meat (buffalo, second quality)',
#  'Meat (camel)',
#  'Meat (chicken)',
#  'Meat (chicken, broiler)',
#  'Meat (chicken, frozen)',
#  'Meat (chicken, imported)',
#  'Meat (chicken, whole)',
#  'Meat (goat)',
#  'Meat (goat, with bones)',
#  'Meat (lamb)',
#  'Meat (mixed, sausage)',
#  'Meat (mutton)',
#  'Meat (pork)',
#  'Meat (pork, first quality)',
#  'Meat (pork, second quality)',
#  'Meat (pork, with fat)',
#  'Meat (veal)',
#  'Milk',
#  'Milk (camel)',
#  'Milk (condensed)',
#  'Milk (cow, pasteurized)',
#  'Milk (non-pasteurized)',
#  'Milk (pasteurized)',
#  'Milk (powder)',
#  'Milk (powder, infant formula)',
#  'Millet',
#  'Millet (white)',
#  'Noodles (short)',
#  'Oil',
#  'Oil (cooking)',
#  'Oil (cotton)',
#  'Oil (groundnut)',
#  'Oil (maize)',
#  'Oil (mixed)',
#  'Oil (mixed, imported)',
#  'Oil (mustard)',
#  'Oil (olive)',
#  'Oil (palm)',
#  'Oil (soybean)',
#  'Oil (sunflower)',
#  'Oil (vegetable)',
#  'Oil (vegetable, imported)',
#  'Oil (vegetable, local)',
#  'Onions',
#  'Onions (dry, local)',
#  'Onions (red)',
#  'Onions (white)',
#  'Oranges (big size)',
#  'Papaya',
#  'Parsley',
#  'Passion fruit',
#  'Pasta',
#  'Peanut',
#  'Peas (dry)',
#  'Peas (fresh)',
#  'Peas (green, dry)',
#  'Peas (split, dry)',
#  'Peas (yellow)',
#  'Peas (yellow, split)',
#  'Peppers (green)',
#  'Plantains',
#  'Plantains (apentu)',
#  'Potatoes',
#  'Potatoes (Dutch)',
#  'Potatoes (Irish)',
#  'Potatoes (Irish, imilla)',
#  'Potatoes (black)',
#  'Potatoes (medium size)',
#  'Potatoes (unica)',
#  'Poultry',
#  'Pulses',
#  'Pumpkin',
#  'Rice',
#  'Rice (basmati, broken)',
#  'Rice (carolina 2da)',
#  'Rice (coarse)',
#  'Rice (denikassia, imported)',
#  'Rice (estaquilla)',
#  'Rice (glutinous, first quality)',
#  'Rice (glutinous, second quality)',
#  'Rice (glutinous, unmilled)',
#  'Rice (good quality)',
#  'Rice (high quality)',
#  'Rice (high quality, local)',
#  'Rice (imported)',
#  'Rice (imported, Egyptian)',
#  'Rice (imported, Indian)',
#  'Rice (imported, Tanzanian)',
#  'Rice (local)',
#  'Rice (long grain)',
#  'Rice (long grain, imported)',
#  'Rice (low quality)',
#  'Rice (low quality, local)',
#  'Rice (medium grain)',
#  'Rice (medium grain, imported)',
#  'Rice (milled 80-20)',
#  'Rice (mixed, low quality)',
#  'Rice (ordinary, first quality)',
#  'Rice (ordinary, second quality)',
#  'Rice (ordinary, unmilled)',
#  'Rice (paddy)',
#  'Rice (paddy, long grain, local)',
#  'Rice (red nadu)',
#  'Rice (regular, milled)',
#  'Rice (small grain, imported)',
#  'Rice (tchako)',
#  'Rice (white)',
#  'Rice (white, imported)',
#  'Salt',
#  'Salt (iodised)',
#  'Sesame',
#  'Sorghum',
#  'Sorghum (berbere)',
#  'Sorghum (brown)',
#  'Sorghum (food aid)',
#  'Sorghum (red)',
#  'Sorghum (taghalit)',
#  'Sorghum (white)',
#  'Sorghum flour',
#  'Sour cream',
#  'Soybeans',
#  'Spinach',
#  'Sugar',
#  'Sugar (brown)',
#  'Sugar (brown, imported)',
#  'Sugar (brown, loaf)',
#  'Sugar (brown, local)',
#  'Sugar (jaggery/gur)',
#  'Sugar (white)',
#  'Sweet potatoes',
#  'Tamarillos/tree tomatoes',
#  'Tea',
#  'Tea (black)',
#  'Tea (green)',
#  'Tea (sahm)',
#  'Tomatoes',
#  'Tomatoes (greenhouse)',
#  'Tomatoes (paste)',
#  'Tortilla (maize)',
#  'Transport (public)',
#  'Wage (non-qualified labour)',
#  'Wage (non-qualified labour, non-agricultural)',
#  'Wage (qualified labour)',
#  'Water (drinking)',
#  'Wheat',
#  'Wheat flour',
#  'Wheat flour (first grade)',
#  'Wheat flour (high quality)',
#  'Wheat flour (imported)',
#  'Wheat flour (local)',
#  'Wheat flour (locally processed)',
#  'Yam',
#  'Yam (Abuja)',
#  'Yam (florido)',
#  'Yogurt',
#  'Zucchini']

# %% [markdown]
# As we see in the commodity name, so we need to add new column called "Commodity Category" by extract the category name from the commodity column

# %%
wfp_df['CommodityCategory'] = wfp_df['CommodityName'].apply(lambda x:x.split('(')[0].strip())
sorted(list(wfp_df['CommodityCategory'].unique()))
# Out:
# ['Apples',
#  'Avocados',
#  'Bananas',
#  'Beans',
#  'Beetroots',
#  'Blackberry',
#  'Bread',
#  'Broccoli',
#  'Buckwheat grits',
#  'Bulgur',
#  'Butter',
#  'Cabbage',
#  'Carrots',
#  'Cashew',
#  'Cassava',
#  'Cassava flour',
#  'Cassava leaves',
#  'Cassava meal',
#  'Cauliflower',
#  'Charcoal',
#  'Cheese',
#  'Chickpeas',
#  'Chili',
#  'Cocoa',
#  'Coffee',
#  'Cornstarch',
#  'Cotton',
#  'Cowpeas',
#  'Cucumbers',
#  'Curd',
#  'Dates',
#  'Eggplants',
#  'Eggs',
#  'Exchange rate',
#  'Fat',
#  'Fish',
#  'Fonio',
#  'Fuel',
#  'Gari',
#  'Garlic',
#  'Ghee',
#  'Groundnuts',
#  'Guava',
#  'Labaneh',
#  'Lentils',
#  'Lettuce',
#  'Livestock',
#  'Maize',
#  'Maize flour',
#  'Maize meal',
#  'Mangoes',
#  'Meat',
#  'Milk',
#  'Millet',
#  'Noodles',
#  'Oil',
#  'Onions',
#  'Oranges',
#  'Papaya',
#  'Parsley',
#  'Passion fruit',
#  'Pasta',
#  'Peanut',
#  'Peas',
#  'Peppers',
#  'Plantains',
#  'Potatoes',
#  'Poultry',
#  'Pulses',
#  'Pumpkin',
#  'Rice',
#  'Salt',
#  'Sesame',
#  'Sorghum',
#  'Sorghum flour',
#  'Sour cream',
#  'Soybeans',
#  'Spinach',
#  'Sugar',
#  'Sweet potatoes',
#  'Tamarillos/tree tomatoes',
#  'Tea',
#  'Tomatoes',
#  'Tortilla',
#  'Transport',
#  'Wage',
#  'Water',
#  'Wheat',
#  'Wheat flour',
#  'Yam',
#  'Yogurt',
#  'Zucchini']

# %% [markdown]
# Perfect, we got commodity category

# %% [markdown]
# #### Clean 'CurrencyName'

# %%
wfp_df['CurrencyName'] = wfp_df['CurrencyName'].str.strip()
sorted(list(wfp_df['CurrencyName'].unique()))
# Out:
# ['AFN',
#  'AMD',
#  'AZN',
#  'BDT',
#  'BIF',
#  'BOB',
#  'BTN',
#  'CDF',
#  'COP',
#  'CVE',
#  'DJF',
#  'DZD',
#  'EGP',
#  'ETB',
#  'GEL',
#  'GHS',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'HTG',
#  'IDR',
#  'INR',
#  'IQD',
#  'IRR',
#  'JOD',
#  'KES',
#  'KGS',
#  'KHR',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'MGA',
#  'MMK',
#  'MRO',
#  'MWK',
#  'MZN',
#  'NGN',
#  'NIS',
#  'NPR',
#  'PEN',
#  'PHP',
#  'PKR',
#  'RWF',
#  'SDG',
#  'SOS',
#  'SSP',
#  'SYP',
#  'SZL',
#  'Somaliland Shilling',
#  'TJS',
#  'TRY',
#  'TZS',
#  'UAH',
#  'UGX',
#  'USD',
#  'XAF',
#  'XOF',
#  'YER',
#  'ZMW']

# %% [markdown]
# We just need to replace "Somaliland Shilling" with his code

# %%
wfp_df['CurrencyName'] = wfp_df['CurrencyName'].replace('Somaliland Shilling','SOS')

# %% [markdown]
# Cool, CurrencyName is perfect now

# %% [markdown]
# #### Clean 'MarketTypeName'

# %%
wfp_df['MarketTypeName'] = wfp_df['MarketTypeName'].str.strip()
sorted(list(wfp_df['MarketTypeName'].unique()))
# Out:
# ['Farm Gate', 'Producer', 'Retail', 'Wholesale']

# %% [markdown]
# Cool, MarketTypeName is perfect now

# %% [markdown]
# #### Clean 'MeasurementName'

# %%
wfp_df['MeasurementName'] = wfp_df['MeasurementName'].str.strip()
sorted(list(wfp_df['MeasurementName'].unique()))
# Out:
# ['1.5 KG',
#  '1.5 L',
#  '1.8 KG',
#  '10 KG',
#  '10 pcs',
#  '100 KG',
#  '100 Tubers',
#  '11.5 KG',
#  '115 G',
#  '12 KG',
#  '12.5 KG',
#  '125 G',
#  '150 G',
#  '160 G',
#  '168 G',
#  '18 KG',
#  '185 G',
#  '2 KG',
#  '200 G',
#  '25 KG',
#  '3 KG',
#  '3 L',
#  '3.5 KG',
#  '30 pcs',
#  '300 G',
#  '350 G',
#  '380 G',
#  '385 G',
#  '400 G',
#  '45 KG',
#  '5 KG',
#  '5 L',
#  '50 KG',
#  '500 G',
#  '500 ML',
#  '60 KG',
#  '650 G',
#  '750 G',
#  '750 ML',
#  '85 G',
#  '90 KG',
#  '91 KG',
#  'Bunch',
#  'Course',
#  'Cuartilla',
#  'Cubic meter',
#  'Day',
#  'Dozen',
#  'Gallon',
#  'Head',
#  'KG',
#  'L',
#  'Libra',
#  'Loaf',
#  'MT',
#  'Marmite',
#  'Month',
#  'Packet',
#  'Pound',
#  'Sack',
#  'USD/LCU',
#  'Unit']

# %% [markdown]
# We need to slice the column to amount and name, so we will add new "MeasurementAmount" coulmn

# %%
wfp_df['Measurement'] = wfp_df['MeasurementName'].apply(lambda x: re.sub(r'\d+|\s|\.', '', x))
sorted(list(wfp_df['Measurement'].unique()))
# Out:
# ['Bunch',
#  'Course',
#  'Cuartilla',
#  'Cubicmeter',
#  'Day',
#  'Dozen',
#  'G',
#  'Gallon',
#  'Head',
#  'KG',
#  'L',
#  'Libra',
#  'Loaf',
#  'ML',
#  'MT',
#  'Marmite',
#  'Month',
#  'Packet',
#  'Pound',
#  'Sack',
#  'Tubers',
#  'USD/LCU',
#  'Unit',
#  'pcs']

# %% [markdown]
# Cool, now we will remove the measurement name from the original column and save the amount

# %%
wfp_df['MeasurementAmount'] = wfp_df['MeasurementName'].apply(lambda x: re.findall(r'^(\d+)', x)[0] if re.match(r'^\d+', x) else 1)
wfp_df = wfp_df.drop(columns = "MeasurementName")
wfp_df['MeasurementAmount'].unique()
# Out:
# array(['100', 1, '750', '50', '350', '45', '1', '10', '90', '500', '400',
#        '18', '385', '91', '168', '11', '150', '12', '300', '2', '160',
#        '380', '85', '60', '25', '3', '650', '185', '125', '115', '5',
#        '200', '30'], dtype=object)

# %% [markdown]
# Cool, The column MeasurementName is clean now

# %%
wfp_df['CommeditySource'] = wfp_df['CommeditySource'].astype(str)
wfp_df['CommeditySource'] = wfp_df['CommeditySource'].str.strip()
sorted(list(wfp_df['CommeditySource'].unique()))
# Out:
# ['ABPMDD, MoAD',
#  'ACF/ACTED/Solidarite/WFP',
#  'AGRITEX',
#  'AGRONET',
#  'AMO-MAFF',
#  'Agricultural Marketing Office, Ministry of Agriculture, Forestry and Fisheries',
#  'Agritex Markets Monitoring System',
#  'Arid Lands Resource Management Project (ALRMP)',
#  'BOS',
#  'BPS (National Statistics Agency)',
#  'Bank of South Sudan',
#  'Bureau of Agricultural Statistics',
#  'CAC',
#  'CAPMAS',
#  'CBI',
#  'CCI',
#  'CENSUS',
#  'CENTRAL LA MAYORISTA',
#  'CEPETCO',
#  'CNSA / FEWS Net',
#  'CNSA / FEWSNET',
#  'CNSA / FEWSNet',
#  'CNSA/FEWSNET',
#  'CNSA/FewsNet',
#  'CSA',
#  'CSO',
#  'Census',
#  'Centeral Bank of Iran',
#  'Centeral bank of Iran',
#  'Central Bank of Iran',
#  'Central Statistics Office',
#  'Central bank of Iran',
#  'Ceylon Petroleum Cooperation',
#  'Ceylon Petroleum Corporation (CEPETCO)',
#  'DA-BAS',
#  'DCS',
#  'DD/DAADER Extrême-Nord / WFP',
#  'DDADER Extrême-Nord / WFP',
#  'DPAE',
#  'DRADER Extrême-Nord / WFP',
#  'DRADER Nord/WFP',
#  'Department of Census & Statistics',
#  'Department of Statistics',
#  'EGTE',
#  'EWS',
#  'Energy Regulatory Commision',
#  'Energy Regulatory Commission (ERC)',
#  'Energy regulatory Commission (ERC)',
#  'FAO',
#  'FAO GIEWS',
#  'FAO-WFP',
#  'FAO/PAM/INS',
#  'FAO/WFP/Ministry of agriculture',
#  'FDTA-Valles',
#  'FESNET Markets Monitoring',
#  'FESNETS Markets Monitoring',
#  'FEWS NET',
#  'FEWS NET Zambia',
#  'FEWS NET, Chad',
#  'FEWS NET, Nigeria',
#  'FEWS.NET',
#  'FEWS.Net',
#  'FEWSNET',
#  'FEWSNET Markets Monitoring',
#  'FEWSNET Markets Monitoring System',
#  'Field Monitors/Sub Offices',
#  'Field monitors',
#  'GBOS',
#  'GNB WFP CO',
#  'GOV',
#  'Gambia Bureau of Statistics (GBOS)',
#  'Gov',
#  'Government',
#  'Government of Benin',
#  'Gvt',
#  'HARTI',
#  'Hector Kobbekaduwa Agrarian Research & Training Institute (HARTI)',
#  'Hector Kobbekaduwa Agrarian Research and Training institute (HARTI)',
#  'ICASEES',
#  'IDSC',
#  'IDSC (Information Decision Support Center of the Cabinet)',
#  'INE',
#  'INEI',
#  'INEI (http://iinei.inei.gob.pe/iinei/siemweb/publico/)',
#  'INS, Katanga',
#  'ISTEEBU',
#  'Information Decision Support Center',
#  'Information Decision Support Center for the Cabinet',
#  'Information Decision Support Center of the Cabinet',
#  'Information Decision Support Center of the Cabinet www.agriprice.idsc.net',
#  'Information Decision Supppoirt Center of the Cabinet',
#  'Infotrade',
#  'Institute of Statistics',
#  'Instituto Nacional de Estatistica, INE',
#  'Iranian centeral bank',
#  'Kenya National Bureau of Statistics (KNBS)',
#  'LISGIS',
#  'M/o Consumer Affairs, Food and Public Distribution, Government of India',
#  'MAG',
#  'MEH',
#  'MFPA Division/HARTI',
#  'MIAL +mVAM',
#  'MINAGRI',
#  'MINAGRI, NKivu',
#  'MITM',
#  'MOFA',
#  'Mantional Institute of Statistics',
#  'Market survey',
#  'Marketing, Food Policy and Agri-Business Division',
#  'Ministry of Agriculture',
#  'Ministry of Agriculture (MAG)',
#  'Ministry of Agriculture (MOA)',
#  'Ministry of Agriculture and Food Security',
#  'Ministry of Agriculture and livestock',
#  'Ministry of Agriculture and livestock/PROSANUT',
#  'Ministry of Energy and Mines',
#  'Ministry of Finance (MoF)',
#  'Ministry of Industry and Commcer',
#  'Ministry of Industry and Commerce',
#  'Ministry of Industry and Commerce, Department of Domestic Trade',
#  'Ministry of Industry and Trade',
#  'MoA',
#  'MoIT',
#  'NSC',
#  'National Bank of Ethiopia',
#  'National Drought Management Authority (NDMA)',
#  'National Institute Of Statistics (INS)',
#  'National Institute of Statistics',
#  'National Maize Cooperation',
#  'National Maize Coorperation',
#  'National Maize Corporation',
#  'National Staitics Committee in the Kyrgyz Republic',
#  'National Statistics Bureau',
#  'National Statistics Committee in Kyrgyz Republic',
#  'National Statistics Committee in the Kyrgyz Republic',
#  'National Statistics Committee of Kyrgyz Republic',
#  'National Statitics Committee of Kyrgyz Republic',
#  'OANDA',
#  'OCPV',
#  'ODR',
#  'OMA',
#  'OMH',
#  'ONASA',
#  'Observatoire du Riz (ODR)',
#  'PAM',
#  'PCBS',
#  'PLAZA CORABASTOS',
#  'Pakistan Bureau of Statics',
#  'Pakistan Bureau of Statistics',
#  'Pakistan Bureau of statistics',
#  'Philippine Statistics Authority',
#  'Price Monitoring System of Honduras (SIMPAH-FHIA)',
#  'Primary Data WFP CO Food aid monitors',
#  'Program Unit SO Tindouf Algeria',
#  'RESIMAO',
#  'RRD',
#  'Retailers',
#  'SB_Bukavu',
#  'SB_Goma',
#  'SIM/SONAGESS',
#  'SIMA',
#  'SIMA - Niger',
#  'SIMA NIGER',
#  'SIMPA',
#  'SIMPA & WFP',
#  'SIMPA&Fews.Net',
#  'SIMPAH',
#  'SIMPAH-FHIA',
#  'SIMPAH-FIAH',
#  'SIMPAH/FHIA',
#  'SIPAG',
#  'SO WFP',
#  'Sub Offices Field Monitors',
#  'Tentative OMA',
#  'Tentative SIMA',
#  'Tentative WFP',
#  'The Gambia Bureau of Statistics',
#  'The State Statistical Committee of the Republic of Azerbaijan',
#  'Turkish Statistical Institute',
#  'UBOS',
#  'VAM Unit SO Tindouf',
#  'VAM-WFPDJIBOUTI SOURCE',
#  'WFP',
#  'WFP - GW',
#  'WFP - Monthly Market Monitor',
#  'WFP CO',
#  'WFP Cambodia',
#  'WFP Guinea- Bissau',
#  'WFP LIRCO',
#  'WFP Market Price Monitoring',
#  'WFP Market Survey',
#  'WFP Markets Monitoring System',
#  'WFP Monitoring',
#  'WFP Sub-Offices',
#  'WFP Sub-office',
#  'WFP UGCO',
#  'WFP and Cooperating Partners',
#  'WFP and NGO Parnters',
#  'WFP and NGO Partners',
#  'WFP and Partner NGOs',
#  'WFP and Partners',
#  'WFP markets monitoring',
#  'WFP monitoring',
#  'WFP, SO',
#  'WFP- FO',
#  'WFP- SO',
#  'WFP-DJCO SOURCE',
#  'WFP-DJIBOUTI',
#  'WFP-DJICO SOURCE',
#  'WFP/',
#  'WFP/Contry Office_Kinshasa',
#  'WFP/FSMS',
#  'WFP/SB-Bukavu',
#  'WFP/SB-Bunia',
#  'WFP/SB-Goma',
#  'WFP/SB-Kabalo',
#  'WFP/SB-Kalemie',
#  'WFP/SB-Kindu',
#  'WFP/SB-Lubumbashi',
#  'WFP/SB-Mbandaka',
#  'WFP/SB-Moba',
#  'WFP/SB-Uvira',
#  'WFP/VAM-M&E',
#  'WFPCO',
#  'WFP_Source',
#  'Website of Department of Agricultural Marketing',
#  'central bank of Iran',
#  'http://iinei.inei.gob.pe/iinei/siemweb/publico/',
#  'http://obiee.banrep.gov.co/',
#  'http://www.cavasa.com.co/precios-mercadeo.php',
#  'http://www.centroabastos.com/web/',
#  'http://www.corabastos.com.co/historico/reportes/',
#  'http://www.dane.gov.co/index.php/indicadores-economicos-new',
#  'http://www.fedearroz.com.co/',
#  'http://www.fedearroz.com.co/new/precios.php',
#  'http://www.lamayorista.com.co',
#  'http://www.mintrabajo.gov.co',
#  'https://www.minminas.gov.co/precios-de-combustible',
#  'mVAM WFP',
#  'www.minminas.gov.co/']

# %% [markdown]
# There are many of duplicated data with mistakes in the names, so we need to correct them by getting the right names and reduce the name too

# %%
CommeditySourceCorrection = {
    'http://www.corabastos.com.co/historico/reportes/':'Corabastos',
    'http://www.dane.gov.co/index.php/indicadores-economicos-new':'DANE GOV',
    'http://www.fedearroz.com.co/':'Fedearroz',
    'http://www.fedearroz.com.co/new/precios.php':'Fedearroz',
    'http://www.lamayorista.com.co':'LaMayorista',
    'http://www.mintrabajo.gov.co':'Ministerio del trabajo',
    'https://www.minminas.gov.co/precios-de-combustible':'Ministry of Mines and Energy',
    'www.minminas.gov.co/':'Ministry of Mines and Energy',
    'AGRITEX':'AGRITEX',
    'Agritex Markets Monitoring System':'AGRITEX',
    'Agricultural Marketing Office':'AMS',
    'Website of Department of Agricultural Marketing':'AMS',
    'Bureau of Agricultural Statistics':'PCBS',
    'Gambia Bureau of Statistics (GBOS)':'GBOS',
    'National Statistics Bureau':'NSB',
    'Census':'CENSUS',
    'Centeral Bank of Iran':'Central Bank of Iran',
    'Central bank of Iran':'Central Bank of Iran',
    'Centeral bank of Iran':'Central Bank of Iran',
    'http://www.lamayorista.com.co':'CENTRAL LA MAYORISTA',
    'Ceylon Petroleum Corporation (CEPETCO)':'CEPETCO',
    'Ceylon Petroleum Cooperation':'CEPETCO',
    'CNSA / FEWS Net':'CNSA/FEWS Net',
    'CNSA / FEWSNET':'CNSA/FEWS Net',
    'CNSA / FEWSNet':'CNSA/FEWS Net',
    'CNSA/FEWSNET':'CNSA/FEWS Net',
    'CNSA/FewsNet':'CNSA/FEWS Net',
    'DD/DAADER Extrême-Nord / WFP':'DAADER Extrême-Nord, WFP',
    'DDADER Extrême-Nord / WFP':'DAADER Extrême-Nord, WFP',
    'DRADER Nord/WFP':'DAADER Extrême-Nord, WFP',
    'DRADER Extrême-Nord / WFP':'DAADER Extrême-Nord, WFP',
    'Department of Statistics':'PCBS',
    'Energy Regulatory Commision':'ERC',
    'Energy Regulatory Commission (ERC)':'ERC',
    'Energy regulatory Commission (ERC)':'ERC',
    'FAO GIEWS':'FAO',
    'FAO-WFP':'FAO, WFP',
    'FESNET Markets Monitoring':'FEWS NET',
    'FESNETS Markets Monitoring':'FEWS NET',
    'FEWS.NET':'FEWS NET',
    'FEWS.Net':'FEWS NET',
    'FEWSNET':'FEWS NET',
    'FEWSNET Markets Monitoring':'FEWS NET',
    'FEWSNET Markets Monitoring System':'FEWS NET',
    'FEWS NET, Nigeria':'FEWS NET',
    'FEWS NET, Chad':'FEWS NET',
    'FEWS NET Zambia':'FEWS NET',
    'Field monitors':'Field Monitors',
    'Field Monitors/Sub Offices':'Field Monitors',
    'Sub Offices Field Monitors':'Field Monitors',
    'Government':'GOV',
    'Gov':'GOV',
    'Hector Kobbekaduwa Agrarian Research & Training Institute (HARTI)':'HARTI',
    'Hector Kobbekaduwa Agrarian Research and Training institute (HARTI)':'HARTI',
    'IDSC (Information Decision Support Center of the Cabinet)':'IDSC',
    'Information Decision Support Center of the Cabinet www.agriprice.idsc.net':'IDSC',
    'Instituto Nacional de Estatistica, INE':'INE',
    'INEI (http://iinei.inei.gob.pe/iinei/siemweb/publico/)':'INEI',
    'http://iinei.inei.gob.pe/iinei/siemweb/publico/':'INEI',
    'Institute of Statistics':'INS',
    'National Institute Of Statistics (INS)':'INS',
    'National Institute of Statistics':'INS',
    'Mantional Institute of Statistics':'INS',
    'Information Decision Support Center':'IDSC',
    'Information Decision Support Center for the Cabinet':'IDSC',
    'Information Decision Support Center of the Cabinet':'IDSC',
    'Information Decision Support Center of the Cabinet www.agriprice.idsc.net':'IDSC',
    'Information Decision Supppoirt Center of the Cabinet':'IDSC',
    'Iranian centeral bank':'CBI',
    'Ministry of Agriculture (MAG)':'MOA',
    'Ministry of Agriculture (MOA)':'MOA',
    'MAG':'MOA',
    'MoA':'MOA',
    'Ministry of Agriculture and Food Security':'MOA',
    'Ministry of Agriculture and livestock':'MOA',
    'Ministry of Agriculture and livestock/PROSANUT':'MOA',
    'Market survey':'WFP',
    'Ministry of Agriculture':'MOA',
    'Ministry of Finance (MoF)':'MOFA',
    'Ministry of Industry and Commcer':'Ministry of Industry and Commerce',
    'Ministry of Industry and Commerce, Department of Domestic Trade':'Ministry of Industry and Commerce',
    'National Maize Cooperation':'National Maize Corporation',
    'National Maize Coorperation':'National Maize Corporation',
    'National Staitics Committee in the Kyrgyz Republic':'NSC',
    'National Statistics Committee in Kyrgyz Republic':'NSC',
    'National Statistics Committee in the Kyrgyz Republic':'NSC',
    'National Statistics Committee of Kyrgyz Republic':'NSC',
    'National Statitics Committee of Kyrgyz Republic':'NSC',
    'Observatoire du Riz (ODR)':'ODR',
    'http://www.corabastos.com.co/historico/reportes/':'PLAZA CORABASTOS',
    'Pakistan Bureau of Statics':'Pakistan Bureau of Statistics',
    'Pakistan Bureau of statistics':'Pakistan Bureau of Statistics',
    'Price Monitoring System of Honduras (SIMPAH-FHIA)':'SIMPAH FHIA',
    'SIMPAH':'SIMPAH FHIA',
    'SIMPAH-FHIA':'SIMPAH FHIA',
    'SIMPAH-FIAH':'SIMPAH FHIA',
    'SIMPAH/FHIA':'SIMPAH FHIA',
    'SO WFP':'WFP',
    'Tentative WFP':'WFP',
    'The Gambia Bureau of Statistics':'GBOS',
    'WFP - GW':'WFP',
    'WFP - Monthly Market Monitor':'WFP',
    'WFP CO':'WFP',
    'WFP Cambodia':'WFP',
    'WFP Guinea- Bissau':'WFP',
    'WFP LIRCO':'WFP',
    'WFP Market Price Monitoring':'WFP',
    'WFP Market Survey':'WFP',
    'WFP Markets Monitoring System':'WFP',
    'WFP Monitoring':'WFP',
    'WFP Sub-Offices':'WFP',
    'WFP Sub-office':'WFP',
    'WFP UGCO':'WFP',
    'WFP and Cooperating Partners':'WFP',
    'WFP and NGO Parnters':'WFP',
    'WFP and NGO Partners':'WFP',
    'WFP and Partner NGOs':'WFP',
    'WFP and Partners':'WFP',
    'WFP markets monitoring':'WFP',
    'WFP monitoring':'WFP',
    'WFP, SO':'WFP',
    'WFP- FO':'WFP',
    'WFP- SO':'WFP',
    'WFP-DJCO SOURCE':'WFP',
    'WFP-DJIBOUTI':'WFP',
    'WFP-DJICO SOURCE':'WFP',
    'WFP/':'WFP',
    'WFP/Contry Office_Kinshasa':'WFP',
    'WFP/FSMS':'WFP',
    'WFP/SB-Bukavu':'WFP',
    'WFP/SB-Bunia':'WFP',
    'WFP/SB-Goma':'WFP',
    'WFP/SB-Kabalo':'WFP',
    'WFP/SB-Kalemie':'WFP',
    'WFP/SB-Kindu':'WFP',
    'WFP/SB-Lubumbashi':'WFP',
    'WFP/SB-Mbandaka':'WFP',
    'WFP/SB-Moba':'WFP',
    'mVAM WFP':'WFP',
    'WFP/SB-Uvira':'WFP',
    'WFP/VAM-M&E':'WFP',
    'WFPCO':'WFP',
    'WFP_Source':'WFP',
    'http://obiee.banrep.gov.co/':'Obiee Banrep ',
    'http://www.cavasa.com.co/precios-mercadeo.php':'Cavasa',
    'http://www.centroabastos.com/web/':'Centroabastos',
    'SIMA':'SIMA NIGER',
    'SIMA - Niger':'SIMA NIGER',
    'SIMA NIGER':'SIMA NIGER',
    'central bank of Iran':'Central Bank of Iran'
}
wfp_df['CommeditySource'] = wfp_df['CommeditySource'].replace(CommeditySourceCorrection)
sorted(list(wfp_df['CommeditySource'].unique()))
# Out:
# ['ABPMDD, MoAD',
#  'ACF/ACTED/Solidarite/WFP',
#  'AGRITEX',
#  'AGRONET',
#  'AMO-MAFF',
#  'AMS',
#  'Agricultural Marketing Office, Ministry of Agriculture, Forestry and Fisheries',
#  'Arid Lands Resource Management Project (ALRMP)',
#  'BOS',
#  'BPS (National Statistics Agency)',
#  'Bank of South Sudan',
#  'CAC',
#  'CAPMAS',
#  'CBI',
#  'CCI',
#  'CENSUS',
#  'CENTRAL LA MAYORISTA',
#  'CEPETCO',
#  'CNSA/FEWS Net',
#  'CSA',
#  'CSO',
#  'Cavasa',
#  'Central Bank of Iran',
#  'Central Statistics Office',
#  'Centroabastos',
#  'DA-BAS',
#  'DAADER Extrême-Nord, WFP',
#  'DANE GOV',
#  'DCS',
#  'DPAE',
#  'Department of Census & Statistics',
#  'EGTE',
#  'ERC',
#  'EWS',
#  'FAO',
#  'FAO, WFP',
#  'FAO/PAM/INS',
#  'FAO/WFP/Ministry of agriculture',
#  'FDTA-Valles',
#  'FEWS NET',
#  'Fedearroz',
#  'Field Monitors',
#  'GBOS',
#  'GNB WFP CO',
#  'GOV',
#  'Government of Benin',
#  'Gvt',
#  'HARTI',
#  'ICASEES',
#  'IDSC',
#  'INE',
#  'INEI',
#  'INS',
#  'INS, Katanga',
#  'ISTEEBU',
#  'Infotrade',
#  'Kenya National Bureau of Statistics (KNBS)',
#  'LISGIS',
#  'M/o Consumer Affairs, Food and Public Distribution, Government of India',
#  'MEH',
#  'MFPA Division/HARTI',
#  'MIAL +mVAM',
#  'MINAGRI',
#  'MINAGRI, NKivu',
#  'MITM',
#  'MOA',
#  'MOFA',
#  'Marketing, Food Policy and Agri-Business Division',
#  'Ministerio del trabajo',
#  'Ministry of Energy and Mines',
#  'Ministry of Industry and Commerce',
#  'Ministry of Industry and Trade',
#  'Ministry of Mines and Energy',
#  'MoIT',
#  'NSB',
#  'NSC',
#  'National Bank of Ethiopia',
#  'National Drought Management Authority (NDMA)',
#  'National Maize Corporation',
#  'OANDA',
#  'OCPV',
#  'ODR',
#  'OMA',
#  'OMH',
#  'ONASA',
#  'Obiee Banrep ',
#  'PAM',
#  'PCBS',
#  'PLAZA CORABASTOS',
#  'Pakistan Bureau of Statistics',
#  'Philippine Statistics Authority',
#  'Primary Data WFP CO Food aid monitors',
#  'Program Unit SO Tindouf Algeria',
#  'RESIMAO',
#  'RRD',
#  'Retailers',
#  'SB_Bukavu',
#  'SB_Goma',
#  'SIM/SONAGESS',
#  'SIMA NIGER',
#  'SIMPA',
#  'SIMPA & WFP',
#  'SIMPA&Fews.Net',
#  'SIMPAH FHIA',
#  'SIPAG',
#  'Tentative OMA',
#  'Tentative SIMA',
#  'The State Statistical Committee of the Republic of Azerbaijan',
#  'Turkish Statistical Institute',
#  'UBOS',
#  'VAM Unit SO Tindouf',
#  'VAM-WFPDJIBOUTI SOURCE',
#  'WFP']

# %% [markdown]
# Cool, The CommeditySource column is ready and clean 95% Percent

# %%
wfp_df = wfp_df.rename(columns = {'Price':'Original_Price'})
wfp_df['Original_Price']
# Out:
# 0          63227.2700
# 1          72727.2700
# 2          81961.5400
# 3          73785.7100
# 4         106375.0000
#              ...
# 743909       241.6290
# 743910       171.5594
# 743911       157.5000
# 743912       150.0000
# 743913       169.6491
# Name: Original_Price, Length: 743914, dtype: float64

# %% [markdown]
# #### We need to add a new price in USD, so we will use third party's data to get the exchange rates

# %%
url = 'https://v6.exchangerate-api.com/v6/0f332d104f273c2e17421bf0/latest/USD'
curr_response = requests.get(url)
curr_data = curr_response.json()['conversion_rates']
curr_data
# Out:
# {'USD': 1,
#  'AED': 3.6725,
#  'AFN': 86.0048,
#  'ALL': 98.7272,
#  'AMD': 386.6257,
#  'ANG': 1.79,
#  'AOA': 682.316,
#  'ARS': 246.8654,
#  'AUD': 1.4765,
#  'AWG': 1.79,
#  'AZN': 1.7,
#  'BAM': 1.8124,
#  'BBD': 2.0,
#  'BDT': 108.4492,
#  'BGN': 1.8124,
#  'BHD': 0.376,
#  'BIF': 2809.7374,
#  'BMD': 1.0,
#  'BND': 1.3413,
#  'BOB': 6.928,
#  'BRL': 4.8618,
#  'BSD': 1.0,
#  'BTN': 82.336,
#  'BWP': 13.4685,
#  'BYN': 2.7359,
#  'BZD': 2.0,
#  'CAD': 1.3324,
#  'CDF': 2239.8361,
#  'CHF': 0.9055,
#  'CLP': 802.8131,
#  'CNY': 7.1605,
#  'COP': 4163.6371,
#  'CRC': 543.3402,
#  'CUP': 24.0,
#  'CVE': 102.1794,
#  'CZK': 22.0811,
#  'DJF': 177.721,
#  'DKK': 6.9133,
#  'DOP': 54.841,
#  'DZD': 136.3104,
#  'EGP': 30.9022,
#  'ERN': 15.0,
#  'ETB': 55.0239,
#  'EUR': 0.9268,
#  'FJD': 2.2121,
#  'FKP': 0.7937,
#  'FOK': 6.9133,
#  'GBP': 0.7938,
#  'GEL': 2.6073,
#  'GGP': 0.7937,
#  'GHS': 11.5648,
#  'GIP': 0.7937,
#  'GMD': 60.0367,
#  'GNF': 8532.6372,
#  'GTQ': 7.8388,
#  'GYD': 211.5313,
#  'HKD': 7.8337,
#  'HNL': 24.588,
#  'HRK': 6.982,
#  'HTG': 139.4812,
#  'HUF': 343.0118,
#  'IDR': 14844.4805,
#  'ILS': 3.568,
#  'IMP': 0.7937,
#  'INR': 82.336,
#  'IQD': 1312.546,
#  'IRR': 42043.0731,
#  'ISK': 138.4427,
#  'JEP': 0.7937,
#  'JMD': 154.6282,
#  'JOD': 0.709,
#  'JPY': 139.9048,
#  'KES': 139.8291,
#  'KGS': 87.5835,
#  'KHR': 4095.705,
#  'KID': 1.477,
#  'KMF': 455.8925,
#  'KRW': 1270.1064,
#  'KWD': 0.3074,
#  'KYD': 0.8333,
#  'KZT': 448.47,
#  'LAK': 18198.9186,
#  'LBP': 15000.0,
#  'LKR': 303.9258,
#  'LRD': 173.3408,
#  'LSL': 18.6089,
#  'LYD': 4.8187,
#  'MAD': 10.1151,
#  'MDL': 17.8021,
#  'MGA': 4514.1413,
#  'MKD': 57.1298,
#  'MMK': 2103.5905,
#  'MNT': 3490.0712,
#  'MOP': 8.0686,
#  'MRU': 34.441,
#  'MUR': 45.762,
#  'MVR': 15.4502,
#  'MWK': 1028.0169,
#  'MXN': 17.2393,
#  'MYR': 4.6182,
#  'MZN': 64.0037,
#  'NAD': 18.6089,
#  'NGN': 463.0832,
#  'NIO': 36.6192,
#  'NOK': 10.6793,
#  'NPR': 131.7376,
#  'NZD': 1.6253,
#  'OMR': 0.3845,
#  'PAB': 1.0,
#  'PEN': 3.6437,
#  'PGK': 3.5491,
#  'PHP': 55.8777,
#  'PKR': 287.8592,
#  'PLN': 4.1482,
#  'PYG': 7283.502,
#  'QAR': 3.64,
#  'RON': 4.5978,
#  'RSD': 108.6771,
#  'RUB': 83.8372,
#  'RWF': 1180.2246,
#  'SAR': 3.75,
#  'SBD': 8.3727,
#  'SCR': 14.0828,
#  'SDG': 540.1056,
#  'SEK': 10.7201,
#  'SGD': 1.3413,
#  'SHP': 0.7937,
#  'SLE': 22.6687,
#  'SLL': 22668.7158,
#  'SOS': 568.7818,
#  'SRD': 37.3618,
#  'SSP': 985.1796,
#  'STN': 22.7035,
#  'SYP': 2516.905,
#  'SZL': 18.6089,
#  'THB': 34.5955,
#  'TJS': 10.8942,
#  'TMT': 3.5,
#  'TND': 3.098,
#  'TOP': 2.3246,
#  'TRY': 23.6622,
#  'TTD': 6.7536,
#  'TVD': 1.477,
#  'TWD': 30.6216,
#  'TZS': 2389.1852,
#  'UAH': 36.9469,
#  'UGX': 3710.926,
#  'UYU': 38.7758,
#  'UZS': 11413.7582,
#  'VES': 27.018,
#  'VND': 23499.0797,
#  'VUV': 119.403,
#  'WST': 2.7145,
#  'XAF': 607.8567,
#  'XCD': 2.7,
#  'XDR': 0.7485,
#  'XOF': 607.8567,
#  'XPF': 110.5816,
#  'YER': 250.3876,
#  'ZAR': 18.6063,
#  'ZMW': 19.2239,
#  'ZWL': 5680.9188}

# %%
wfp_df['USDPrice'] = wfp_df['CurrencyName'].map(curr_data)
wfp_df['USDPrice'] = wfp_df['USDPrice'].astype(float)
wfp_df['USDPrice'] = round(wfp_df['USDPrice'],2)
# Reduce the RAM
curr_data = None
wfp_df['USDPrice'].unique()
# Out:
# array([2.389190e+03, 1.861000e+01, 1.394800e+02, 1.084500e+02,
#        6.078600e+02, 2.239840e+03, 1.000000e+00, 5.588000e+01,
#        1.398300e+02, 2.503900e+02, 2.809740e+03, 3.640000e+00,
#        1.484448e+04, 1.156000e+01, 1.700000e+00, 3.866300e+02,
#        3.090000e+01, 3.710930e+03, 1.733400e+02, 6.004000e+01,
#        2.878600e+02, 6.930000e+00, 5.502000e+01, 1.089000e+01,
#        2.610000e+00, 6.400000e+01, 8.532640e+03, 3.039300e+02,
#        1.021800e+02, 7.100000e-01, 1.777200e+02, 4.095700e+03,
#        8.758000e+01, 1.317400e+02, 1.819892e+04,          nan,
#        4.514140e+03, 1.028020e+03, 4.163640e+03, 8.234000e+01,
#        2.103590e+03, 5.401100e+02, 1.180220e+03, 2.516910e+03,
#        5.687800e+02, 7.840000e+00, 9.851800e+02, 1.312550e+03,
#        8.600000e+01, 2.366000e+01, 4.204307e+04, 1.500000e+04,
#        1.363100e+02, 3.695000e+01, 1.922000e+01, 4.630800e+02])

# %%
wfp_df['USDPrice'] = wfp_df['USDPrice'].apply(lambda x:round(x,3))
# Out:
# 2379.442

# %% [markdown]
# ## The Final Result

# %%
wfp_df['MeasurementAmount'].unique()
# Out:
# array(['100', 1, '750', '50', '350', '45', '1', '10', '90', '500', '400',
#        '18', '385', '91', '168', '11', '150', '12', '300', '2', '160',
#        '380', '85', '60', '25', '3', '650', '185', '125', '115', '5',
#        '200', '30'], dtype=object)

# %% [markdown]
# ### Save Transformed data

# %%
wfp_df.to_csv('WFP_Prices.csv', encoding='UTF-8')

# %%
wfp_df.head()
# Out:
#                    CountryName MarketName CommodityName CurrencyName  \
# 0  United Republic of Tanzania     Arusha          Rice          TZS
# 1  United Republic of Tanzania     Arusha          Rice          TZS
# 2  United Republic of Tanzania     Arusha          Rice          TZS
# 3  United Republic of Tanzania     Arusha          Rice          TZS
# 4  United Republic of Tanzania     Arusha          Rice          TZS
#
#   MarketTypeName  Month  Year  Original_Price CommeditySource  \
# 0      Wholesale      1  2006        63227.27            MITM
# 1      Wholesale      2  2006        72727.27            MITM
# 2      Wholesale      3  2006        81961.54            MITM
# 3      Wholesale      4  2006        73785.71            MITM
# 4      Wholesale      5  2006       106375.00            MITM
#
#   CommodityCategory Measurement MeasurementAmount  USDPrice
# 0              Rice          KG               100   2379.44
# 1              Rice          KG               100   2379.44
# 2              Rice          KG               100   2379.44
# 3              Rice          KG               100   2379.44
# 4              Rice          KG               100   2379.44
